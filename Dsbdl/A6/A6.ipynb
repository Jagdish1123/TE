# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.histplot(data=df, x="SepalLengthCm",bins=20, kde=True) 
# sns.histplot(data=df, x="SepalWidthCm",bins=20, kde=True)
# sns.histplot(data=df, x="PetalLengthCm",bins=20, kde=True)
# sns.histplot(data=df, x="PetalWidthCm",bins=20, kde=True)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
sns.boxplot(data=df.drop(["Species","Id"], axis=1))
# Out:
# <Axes: >

# %%
sns.boxplot(data=df, x="Species", y="SepalLengthCm")
# sns.boxplot(data=df, x="Species", y="SepalWidthCm")
# sns.boxplot(data=df, x="Species", y="PetalLengthCm")
# sns.boxplot(data=df, x="Species", y="PetalWidthCm")
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.kdeplot( df , x="SepalLengthCm" )
# sns.kdeplot( df , x="SepalWidthCm" )
# sns.kdeplot( df , x="PetalLengthCm" )
# sns.kdeplot( df , x="PetalWidthCm" )
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Density'>

# %%
sns.heatmap(df.drop(["Species","Id"], axis=1).corr(), annot=True)
# why this ??
# answer: because the correlation between SepalLengthCm and PetalLengthCm is 0.87, which is a strong positive correlation. 
# This means that as the SepalLengthCm increases, the PetalLengthCm also tends to increase. 
# Similarly, the correlation between SepalWidthCm and PetalWidthCm is also strong (0.87). 
# However, the correlation between SepalLengthCm and SepalWidthCm is -0.37, which indicates a weak negative correlation. 
# This means that as the SepalLengthCm increases, the SepalWidthCm tends to decrease slightly.
# Out:
# <Axes: >
